# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ranon Chow
#  <br />English Teacher
#  <br />Data Scientist**

# %% [markdown]
# *I am interested in data science because I would like to advance my career.*

# %% [markdown]
# ### It sums up the numbers of 1 + 1

# %%
1+1
# Out:
# 2

# %% [markdown]
# things I like to do:
# * Watching Netflix
# * Coding
# - Reading
# - Learning

# %% [markdown]
# | My Books    | Description |
# | ----------- | ----------- |
# | Sapiens     | Good        |
# | Coding101   | Nice.       |
# | Psych101    | Not Bad     |

# %% [markdown]
# | My Class   | Description |
# | ----------- | ----------- |
# | Eng    | Good        |
# | Math   | Nice.       |
# | Psych    | Not Bad     |

# %% [markdown]
# | My Books    | Description |
# | ----------- | ----------- |
# | Sapiens     | Good        |
# | Coding101   | Nice.       |
# | Psych101    | Not Bad     |

# %% [markdown]
# ![images-1.jpg](attachment:images-1.jpg)
# ![images-2.jpg](attachment:images-2.jpg)

# %% [markdown]
# A [link](http://example.com "Title").
# A [link](http://example.com "Title").
# A [link](http://example.com "Title").

# %% [markdown]
# ![MarineGEO_logo.png](attachment:MarineGEO_logo.png)

# %% [markdown]
# 1. Item1
# 2. Item2
# 3. Item3
#  <hr />
#
# ~~~~
# This is a
# piece of code
# in a block
# ~~~~
#
# ```
# This too
# ```
#
#  <hr />
#  ~~double tildes1~~ .
# ~~double tildes2~~
# ~~double tildes3~~

# %% [markdown]
#  > We need a bigger boat.
#  >>How big?

# %% [markdown]
#  > Life is like a box of chocolates
#  >>Yummy!

# %% [markdown]
#  > Houston, we have a problem.
#  >> Uh, oh.
